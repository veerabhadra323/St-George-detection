# %%
import os
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# Out:
# 2024-07-29 23:15:57.519082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-29 23:15:57.536461: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-29 23:15:57.541954: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-29 23:15:57.553508: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-29 23:15:58.599487: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Directory paths
TRAIN_DIR = 'Dataset'
TEST_DIR = 'Dataset'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in ['georges', 'no_georges']:  # Explicitly list the folder names
        label_path = os.path.join(dir, label)
        if not os.path.exists(label_path):
            print(f"Directory {label_path} does not exist.")
            continue
        for imagename in os.listdir(label_path):
            image_paths.append(os.path.join(label_path, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
# Create DataFrames for the training and testing datasets
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# georges completed
# no_georges completed
# georges completed
# no_georges completed

# %%
# Feature extraction
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode='grayscale', target_size=(48, 48))
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])
test_features = extract_features(test['image'])

x_train = train_features / 255.0
x_test = test_features / 255.0
# Out:
#   0%|          | 0/6047 [00:00<?, ?it/s]
#   0%|          | 0/6047 [00:00<?, ?it/s]

# %%
# Label encoding
le = LabelEncoder()
le.fit(train['label'])
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# Update number of classes for St. George classification
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %%
# Define the model
model = Sequential()

# First Conv layer with 128 filters, kernel size 3x3, and ReLU activation
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Second Conv layer with 256 filters, kernel size 3x3, and ReLU activation
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Third Conv layer with 512 filters, kernel size 3x3, and ReLU activation
model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Fourth Conv layer with 512 filters, kernel size 3x3, and ReLU activation
model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Flatten the output from the Conv layers
model.add(Flatten())

# Dense layer with 512 units and ReLU activation
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

# Dense layer with 256 units and ReLU activation
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Output layer with 2 units (for binary classification) and softmax activation
model.add(Dense(2, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 46, 46, 128)       1280
#
#  max_pooling2d_4 (MaxPoolin  (None, 23, 23, 128)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 23, 23, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_5 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 10, 10, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 512)         0
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 512)         2359808
#
#  max_pooling2d_7 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 1, 1, 512)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4230914 (16.14 MB)
# Trainable params: 4230914 (16.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the model
history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 48/48 [==============================] - 6s 73ms/step - loss: 0.6857 - accuracy: 0.5527 - val_loss: 0.6733 - val_accuracy: 0.5689
# Epoch 2/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.6391 - accuracy: 0.6163 - val_loss: 0.6354 - val_accuracy: 0.6370
# Epoch 3/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.6251 - accuracy: 0.6557 - val_loss: 0.6651 - val_accuracy: 0.5990
# Epoch 4/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.5870 - accuracy: 0.6893 - val_loss: 0.5653 - val_accuracy: 0.7346
# Epoch 5/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.5487 - accuracy: 0.7205 - val_loss: 0.5913 - val_accuracy: 0.6840
# Epoch 6/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.5321 - accuracy: 0.7278 - val_loss: 0.5502 - val_accuracy: 0.7266
# Epoch 7/100
# 48/48 [==============================] - 4s 76ms/step - loss: 0.5263 - accuracy: 0.7432 - val_loss: 0.4836 - val_accuracy: 0.7690
# Epoch 8/100
# 48/48 [==============================] - 3s 71ms/step - loss: 0.5072 - accuracy: 0.7556 - val_loss: 0.5403 - val_accuracy: 0.7194
# Epoch 9/100
# 48/48 [==============================] - 3s 66ms/step - loss: 0.4931 - accuracy: 0.7653 - val_loss: 0.5145 - val_accuracy: 0.7485
# Epoch 10/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.4764 - accuracy: 0.7691 - val_loss: 0.4647 - val_accuracy: 0.7806
# Epoch 11/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.4801 - accuracy: 0.7716 - val_loss: 0.4328 - val_accuracy: 0.8052
# Epoch 12/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.4731 - accuracy: 0.7769 - val_loss: 0.4796 - val_accuracy: 0.7753
# Epoch 13/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.4686 - accuracy: 0.7772 - val_loss: 0.4672 - val_accuracy: 0.7731
# Epoch 14/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.4576 - accuracy: 0.7858 - val_loss: 0.3898 - val_accuracy: 0.8381
# Epoch 15/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.4287 - accuracy: 0.8002 - val_loss: 0.3606 - val_accuracy: 0.8429
# Epoch 16/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.4441 - accuracy: 0.7900 - val_loss: 0.3652 - val_accuracy: 0.8391
# Epoch 17/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.4180 - accuracy: 0.8090 - val_loss: 0.3713 - val_accuracy: 0.8389
# Epoch 18/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.4045 - accuracy: 0.8128 - val_loss: 0.3390 - val_accuracy: 0.8573
# Epoch 19/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.3976 - accuracy: 0.8194 - val_loss: 0.3436 - val_accuracy: 0.8654
# Epoch 20/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.3922 - accuracy: 0.8257 - val_loss: 0.3205 - val_accuracy: 0.8743
# Epoch 21/100
# 48/48 [==============================] - 3s 65ms/step - loss: 0.3797 - accuracy: 0.8288 - val_loss: 0.2888 - val_accuracy: 0.8885
# Epoch 22/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.3708 - accuracy: 0.8317 - val_loss: 0.2900 - val_accuracy: 0.8894
# Epoch 23/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.3658 - accuracy: 0.8335 - val_loss: 0.2722 - val_accuracy: 0.9046
# Epoch 24/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.3491 - accuracy: 0.8454 - val_loss: 0.2660 - val_accuracy: 0.9000
# Epoch 25/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.3344 - accuracy: 0.8455 - val_loss: 0.2333 - val_accuracy: 0.9191
# Epoch 26/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.3358 - accuracy: 0.8525 - val_loss: 0.2537 - val_accuracy: 0.9062
# Epoch 27/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.3227 - accuracy: 0.8603 - val_loss: 0.2430 - val_accuracy: 0.9168
# Epoch 28/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.3192 - accuracy: 0.8606 - val_loss: 0.2812 - val_accuracy: 0.8928
# Epoch 29/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.3078 - accuracy: 0.8639 - val_loss: 0.2014 - val_accuracy: 0.9360
# Epoch 30/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.3070 - accuracy: 0.8632 - val_loss: 0.1673 - val_accuracy: 0.9416
# Epoch 31/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2960 - accuracy: 0.8723 - val_loss: 0.1902 - val_accuracy: 0.9466
# Epoch 32/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.2788 - accuracy: 0.8768 - val_loss: 0.2102 - val_accuracy: 0.9239
# Epoch 33/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2760 - accuracy: 0.8804 - val_loss: 0.1739 - val_accuracy: 0.9479
# Epoch 34/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.2833 - accuracy: 0.8803 - val_loss: 0.1692 - val_accuracy: 0.9411
# Epoch 35/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.2655 - accuracy: 0.8859 - val_loss: 0.1455 - val_accuracy: 0.9578
# Epoch 36/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.2669 - accuracy: 0.8859 - val_loss: 0.1416 - val_accuracy: 0.9583
# Epoch 37/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.2535 - accuracy: 0.8917 - val_loss: 0.1327 - val_accuracy: 0.9601
# Epoch 38/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.2405 - accuracy: 0.8986 - val_loss: 0.1075 - val_accuracy: 0.9697
# Epoch 39/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.2401 - accuracy: 0.8943 - val_loss: 0.1193 - val_accuracy: 0.9633
# Epoch 40/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2308 - accuracy: 0.9034 - val_loss: 0.1293 - val_accuracy: 0.9682
# Epoch 41/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2301 - accuracy: 0.9084 - val_loss: 0.1005 - val_accuracy: 0.9735
# Epoch 42/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2186 - accuracy: 0.9072 - val_loss: 0.1272 - val_accuracy: 0.9626
# Epoch 43/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.2118 - accuracy: 0.9117 - val_loss: 0.1009 - val_accuracy: 0.9711
# Epoch 44/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.2126 - accuracy: 0.9125 - val_loss: 0.0827 - val_accuracy: 0.9775
# Epoch 45/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.2054 - accuracy: 0.9168 - val_loss: 0.1044 - val_accuracy: 0.9696
# Epoch 46/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2151 - accuracy: 0.9095 - val_loss: 0.0961 - val_accuracy: 0.9833
# Epoch 47/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.2027 - accuracy: 0.9130 - val_loss: 0.1020 - val_accuracy: 0.9773
# Epoch 48/100
# 48/48 [==============================] - 3s 64ms/step - loss: 0.1879 - accuracy: 0.9238 - val_loss: 0.0716 - val_accuracy: 0.9833
# Epoch 49/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1907 - accuracy: 0.9210 - val_loss: 0.0757 - val_accuracy: 0.9835
# Epoch 50/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1963 - accuracy: 0.9180 - val_loss: 0.0686 - val_accuracy: 0.9863
# Epoch 51/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1789 - accuracy: 0.9249 - val_loss: 0.0726 - val_accuracy: 0.9833
# Epoch 52/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.1779 - accuracy: 0.9264 - val_loss: 0.0697 - val_accuracy: 0.9864
# Epoch 53/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1829 - accuracy: 0.9231 - val_loss: 0.0555 - val_accuracy: 0.9881
# Epoch 54/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1734 - accuracy: 0.9327 - val_loss: 0.0652 - val_accuracy: 0.9896
# Epoch 55/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1709 - accuracy: 0.9320 - val_loss: 0.0677 - val_accuracy: 0.9850
# Epoch 56/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1761 - accuracy: 0.9289 - val_loss: 0.0543 - val_accuracy: 0.9884
# Epoch 57/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1611 - accuracy: 0.9352 - val_loss: 0.0474 - val_accuracy: 0.9888
# Epoch 58/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1486 - accuracy: 0.9408 - val_loss: 0.0485 - val_accuracy: 0.9899
# Epoch 59/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1722 - accuracy: 0.9327 - val_loss: 0.0612 - val_accuracy: 0.9876
# Epoch 60/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1578 - accuracy: 0.9390 - val_loss: 0.0428 - val_accuracy: 0.9919
# Epoch 61/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1544 - accuracy: 0.9368 - val_loss: 0.0377 - val_accuracy: 0.9944
# Epoch 62/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1535 - accuracy: 0.9391 - val_loss: 0.0541 - val_accuracy: 0.9881
# Epoch 63/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1550 - accuracy: 0.9386 - val_loss: 0.0396 - val_accuracy: 0.9906
# Epoch 64/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1459 - accuracy: 0.9426 - val_loss: 0.0455 - val_accuracy: 0.9917
# Epoch 65/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1549 - accuracy: 0.9378 - val_loss: 0.0516 - val_accuracy: 0.9924
# Epoch 66/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1438 - accuracy: 0.9466 - val_loss: 0.0430 - val_accuracy: 0.9926
# Epoch 67/100
# 48/48 [==============================] - 3s 64ms/step - loss: 0.1518 - accuracy: 0.9406 - val_loss: 0.0405 - val_accuracy: 0.9921
# Epoch 68/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1358 - accuracy: 0.9479 - val_loss: 0.0440 - val_accuracy: 0.9906
# Epoch 69/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1386 - accuracy: 0.9449 - val_loss: 0.0380 - val_accuracy: 0.9931
# Epoch 70/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1425 - accuracy: 0.9415 - val_loss: 0.0349 - val_accuracy: 0.9924
# Epoch 71/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1293 - accuracy: 0.9499 - val_loss: 0.0291 - val_accuracy: 0.9927
# Epoch 72/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1260 - accuracy: 0.9502 - val_loss: 0.0251 - val_accuracy: 0.9947
# Epoch 73/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1298 - accuracy: 0.9491 - val_loss: 0.0340 - val_accuracy: 0.9931
# Epoch 74/100
# 48/48 [==============================] - 3s 60ms/step - loss: 0.1161 - accuracy: 0.9527 - val_loss: 0.0335 - val_accuracy: 0.9914
# Epoch 75/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1340 - accuracy: 0.9501 - val_loss: 0.0335 - val_accuracy: 0.9936
# Epoch 76/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.1259 - accuracy: 0.9482 - val_loss: 0.0259 - val_accuracy: 0.9950
# Epoch 77/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1295 - accuracy: 0.9499 - val_loss: 0.0310 - val_accuracy: 0.9936
# Epoch 78/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1209 - accuracy: 0.9555 - val_loss: 0.0249 - val_accuracy: 0.9955
# Epoch 79/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1017 - accuracy: 0.9600 - val_loss: 0.0181 - val_accuracy: 0.9947
# Epoch 80/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.1108 - accuracy: 0.9560 - val_loss: 0.0214 - val_accuracy: 0.9957
# Epoch 81/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1191 - accuracy: 0.9558 - val_loss: 0.0278 - val_accuracy: 0.9955
# Epoch 82/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.1033 - accuracy: 0.9567 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 83/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1199 - accuracy: 0.9539 - val_loss: 0.0345 - val_accuracy: 0.9934
# Epoch 84/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.1043 - accuracy: 0.9590 - val_loss: 0.0202 - val_accuracy: 0.9947
# Epoch 85/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1175 - accuracy: 0.9530 - val_loss: 0.0213 - val_accuracy: 0.9969
# Epoch 86/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.1120 - accuracy: 0.9578 - val_loss: 0.0417 - val_accuracy: 0.9891
# Epoch 87/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.0930 - accuracy: 0.9646 - val_loss: 0.0231 - val_accuracy: 0.9934
# Epoch 88/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1101 - accuracy: 0.9595 - val_loss: 0.0182 - val_accuracy: 0.9957
# Epoch 89/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1090 - accuracy: 0.9592 - val_loss: 0.0256 - val_accuracy: 0.9955
# Epoch 90/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.1074 - accuracy: 0.9585 - val_loss: 0.0220 - val_accuracy: 0.9959
# Epoch 91/100
# 48/48 [==============================] - 3s 62ms/step - loss: 0.0972 - accuracy: 0.9633 - val_loss: 0.0185 - val_accuracy: 0.9952
# Epoch 92/100
# 48/48 [==============================] - 3s 58ms/step - loss: 0.0945 - accuracy: 0.9653 - val_loss: 0.0185 - val_accuracy: 0.9940
# Epoch 93/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1055 - accuracy: 0.9596 - val_loss: 0.0226 - val_accuracy: 0.9942
# Epoch 94/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.0954 - accuracy: 0.9639 - val_loss: 0.0173 - val_accuracy: 0.9960
# Epoch 95/100
# 48/48 [==============================] - 3s 64ms/step - loss: 0.0972 - accuracy: 0.9625 - val_loss: 0.0303 - val_accuracy: 0.9907
# Epoch 96/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.1071 - accuracy: 0.9592 - val_loss: 0.0161 - val_accuracy: 0.9960
# Epoch 97/100
# 48/48 [==============================] - 3s 61ms/step - loss: 0.0922 - accuracy: 0.9635 - val_loss: 0.0154 - val_accuracy: 0.9959
# Epoch 98/100
# 48/48 [==============================] - 3s 59ms/step - loss: 0.1004 - accuracy: 0.9636 - val_loss: 0.0153 - val_accuracy: 0.9965
# Epoch 99/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.0948 - accuracy: 0.9631 - val_loss: 0.0144 - val_accuracy: 0.9962
# Epoch 100/100
# 48/48 [==============================] - 3s 63ms/step - loss: 0.1037 - accuracy: 0.9613 - val_loss: 0.0187 - val_accuracy: 0.9957

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Predict on the test set
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)

# Convert y_test to class labels
y_test_labels = np.argmax(y_test, axis=1)

# Generate classification report
report = classification_report(y_test_labels, y_pred, target_names=le.classes_)
print(report)
# Out:
# 189/189 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#      georges       0.99      1.00      1.00      2681
#   no_georges       1.00      0.99      1.00      3366
#
#     accuracy                           1.00      6047
#    macro avg       1.00      1.00      1.00      6047
# weighted avg       1.00      1.00      1.00      6047

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Save the entire model (architecture + weights)
model.save("models/st_george_detector.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def display_random_predictions(x_test, y_test_labels, y_pred, le, num_images=10):

    # Randomly select indices
    indices = np.random.choice(len(x_test), size=num_images, replace=False)

    plt.figure(figsize=(12, 12))

    for i, idx in enumerate(indices):
        plt.subplot(5, 5, i + 1)
        plt.imshow(x_test[idx].reshape(48, 48), cmap='gray')
        true_label = le.classes_[y_test_labels[idx]]
        pred_label = le.classes_[y_pred[idx]]
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=10)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Predict on the test set
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)

# Convert y_test to class labels
y_test_labels = np.argmax(y_test, axis=1)

# Display random predictions
display_random_predictions(x_test, y_test_labels, y_pred, le, num_images=10)
# Out:
# 189/189 [==============================] - 1s 4ms/step
